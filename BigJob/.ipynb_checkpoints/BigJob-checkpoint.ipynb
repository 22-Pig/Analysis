# %% [markdown]
# ## 1 数据来源

# %% [markdown]
# ## 2 数据读取

# %%
import pandas as pd
import numpy as np
import pymysql
from mysql import connector
from pandas import DataFrame, Series
from sqlalchemy import create_engine

# mysql账号：root  密码：123123 数据库：bigjob
# 数据表：houseinfo
# 创建数据库引擎
# mysql+pymysql 表示使用Mysql数据库的pymysql驱动
engine = create_engine('mysql+mysqlconnector://root:123123@127.0.0.1/bigjob')
sql = 'select * from houseinfo;'
file_data = pd.read_sql(sql, engine)
file_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [6], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import mysql
#       4 from mysql import connector
#       5 from pandas import DataFrame, Series
#
# ModuleNotFoundError: No module named 'mysql'

# %% [markdown]
# ## 3 数据预处理

# %% [markdown]
# ### 3.1 重复值和空值处理

# %%
# 重复数据检测
file_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13285    False
# 13286    False
# 13287    False
# 13288    False
# 13289    False
# Length: 13290, dtype: bool

# %%
# 删除重复数据，并对file_data重新赋值
file_data = file_data.drop_duplicates()
file_data
# Out:
#           id   区域                                                 链接     小区名称  \
# 0          1  上虞区  https://sx.lianjia.com/ershoufang/103122982067...   闰土•嘉和園
# 1          2  上虞区  https://sx.lianjia.com/ershoufang/103122914260...    绿城桂花园
# 2          3  上虞区  https://sx.lianjia.com/ershoufang/103122978023...     南都花园
# 3          4  上虞区  https://sx.lianjia.com/ershoufang/103122657260...  卧龙·天香西园
# 4          5  上虞区  https://sx.lianjia.com/ershoufang/103122651285...   卧龙天香南园
# ...      ...  ...                                                ...      ...
# 13285  13290  越城区  https://sx.lianjia.com/ershoufang/103121132246...     南星公寓
# 13286  13291  越城区  https://sx.lianjia.com/ershoufang/103119135871...     绍兴艺境
# 13287  13292  越城区  https://sx.lianjia.com/ershoufang/103120662261...     水墨澜庭
# 13288  13293  越城区  https://sx.lianjia.com/ershoufang/103113852581...      御和园
# 13289  13294  越城区  https://sx.lianjia.com/ershoufang/103117268044...    宏大美安居
#
#          位置    户型        面积   朝向 装修风格      均价         总价
# 0      上虞城西  3室1厅  130.85平米    南   简装  220.8万  16,875元/平
# 1      上虞城北  3室2厅  158.48平米    南   精装    280万  17,668元/平
# 2      上虞城南  3室2厅     136平米    南   精装  262.8万  19,324元/平
# 3       开发区  3室1厅    86.4平米    南   精装    190万  21,991元/平
# 4       开发区  4室2厅  139.03平米    南   毛坯    210万  15,105元/平
# ...     ...   ...       ...  ...  ...     ...        ...
# 13285    斗门  3室2厅  142.69平米    南   其他    145万  10,162元/平
# 13286    斗门  4室2厅     127平米    南   其他    230万  18,111元/平
# 13287    城南  5室2厅     226平米  南 北   其他    560万  24,779元/平
# 13288    镜湖  3室2厅     123平米    南   其他    332万  26,992元/平
# 13289    两湖  5室2厅     209平米  南 北   毛坯    180万   8,613元/平
#
# [13290 rows x 11 columns]

# %%
# 删除缺失数据，并对file_data重新赋值
file_data = file_data.dropna()
file_data
# Out:
#           id   区域                                                 链接     小区名称  \
# 0          1  上虞区  https://sx.lianjia.com/ershoufang/103122982067...   闰土•嘉和園
# 1          2  上虞区  https://sx.lianjia.com/ershoufang/103122914260...    绿城桂花园
# 2          3  上虞区  https://sx.lianjia.com/ershoufang/103122978023...     南都花园
# 3          4  上虞区  https://sx.lianjia.com/ershoufang/103122657260...  卧龙·天香西园
# 4          5  上虞区  https://sx.lianjia.com/ershoufang/103122651285...   卧龙天香南园
# ...      ...  ...                                                ...      ...
# 13285  13290  越城区  https://sx.lianjia.com/ershoufang/103121132246...     南星公寓
# 13286  13291  越城区  https://sx.lianjia.com/ershoufang/103119135871...     绍兴艺境
# 13287  13292  越城区  https://sx.lianjia.com/ershoufang/103120662261...     水墨澜庭
# 13288  13293  越城区  https://sx.lianjia.com/ershoufang/103113852581...      御和园
# 13289  13294  越城区  https://sx.lianjia.com/ershoufang/103117268044...    宏大美安居
#
#          位置    户型        面积   朝向 装修风格      均价         总价
# 0      上虞城西  3室1厅  130.85平米    南   简装  220.8万  16,875元/平
# 1      上虞城北  3室2厅  158.48平米    南   精装    280万  17,668元/平
# 2      上虞城南  3室2厅     136平米    南   精装  262.8万  19,324元/平
# 3       开发区  3室1厅    86.4平米    南   精装    190万  21,991元/平
# 4       开发区  4室2厅  139.03平米    南   毛坯    210万  15,105元/平
# ...     ...   ...       ...  ...  ...     ...        ...
# 13285    斗门  3室2厅  142.69平米    南   其他    145万  10,162元/平
# 13286    斗门  4室2厅     127平米    南   其他    230万  18,111元/平
# 13287    城南  5室2厅     226平米  南 北   其他    560万  24,779元/平
# 13288    镜湖  3室2厅     123平米    南   其他    332万  26,992元/平
# 13289    两湖  5室2厅     209平米  南 北   毛坯    180万   8,613元/平
#
# [13290 rows x 11 columns]

# %% [markdown]
# ### 3.2 数据转换类型

# %%
# 创建一个空数组
data_new = np.array([])
# 取出“面积”一列数据，将每个数据末尾的中文字符去除
data = file_data['面积'].values
for i in data:
              data_new = np.append(data_new, np.array(i[:-2]))
# 通过astype()方法将str类型转换为float64类型
data = data_new.astype(np.float64)
# 用新的数据替换
file_data.loc[:,'面积']= data
file_data
# Out:
# C:\Users\shaun\AppData\Local\Temp\ipykernel_34000\1804801087.py:10: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   file_data.loc[:,'面积']= data
#           id   区域                                                 链接     小区名称  \
# 0          1  上虞区  https://sx.lianjia.com/ershoufang/103122982067...   闰土•嘉和園
# 1          2  上虞区  https://sx.lianjia.com/ershoufang/103122914260...    绿城桂花园
# 2          3  上虞区  https://sx.lianjia.com/ershoufang/103122978023...     南都花园
# 3          4  上虞区  https://sx.lianjia.com/ershoufang/103122657260...  卧龙·天香西园
# 4          5  上虞区  https://sx.lianjia.com/ershoufang/103122651285...   卧龙天香南园
# ...      ...  ...                                                ...      ...
# 13285  13290  越城区  https://sx.lianjia.com/ershoufang/103121132246...     南星公寓
# 13286  13291  越城区  https://sx.lianjia.com/ershoufang/103119135871...     绍兴艺境
# 13287  13292  越城区  https://sx.lianjia.com/ershoufang/103120662261...     水墨澜庭
# 13288  13293  越城区  https://sx.lianjia.com/ershoufang/103113852581...      御和园
# 13289  13294  越城区  https://sx.lianjia.com/ershoufang/103117268044...    宏大美安居
#
#          位置    户型      面积   朝向 装修风格      均价         总价
# 0      上虞城西  3室1厅  130.85    南   简装  220.8万  16,875元/平
# 1      上虞城北  3室2厅  158.48    南   精装    280万  17,668元/平
# 2      上虞城南  3室2厅  136.00    南   精装  262.8万  19,324元/平
# 3       开发区  3室1厅   86.40    南   精装    190万  21,991元/平
# 4       开发区  4室2厅  139.03    南   毛坯    210万  15,105元/平
# ...     ...   ...     ...  ...  ...     ...        ...
# 13285    斗门  3室2厅  142.69    南   其他    145万  10,162元/平
# 13286    斗门  4室2厅  127.00    南   其他    230万  18,111元/平
# 13287    城南  5室2厅  226.00  南 北   其他    560万  24,779元/平
# 13288    镜湖  3室2厅  123.00    南   其他    332万  26,992元/平
# 13289    两湖  5室2厅  209.00  南 北   毛坯    180万   8,613元/平
#
# [13290 rows x 11 columns]

# %%
# 获取“户型”一列数据
housetype_data = file_data['户型']
temp_list = []
# 通过replace()方法进行替换
for i in housetype_data:
    new_info = i.replace('房间','室')
    temp_list.append(new_info)
file_data.loc[:,'户型'] = temp_list
file_data
# Out:
#           id   区域                                                 链接     小区名称  \
# 0          1  上虞区  https://sx.lianjia.com/ershoufang/103122982067...   闰土•嘉和園
# 1          2  上虞区  https://sx.lianjia.com/ershoufang/103122914260...    绿城桂花园
# 2          3  上虞区  https://sx.lianjia.com/ershoufang/103122978023...     南都花园
# 3          4  上虞区  https://sx.lianjia.com/ershoufang/103122657260...  卧龙·天香西园
# 4          5  上虞区  https://sx.lianjia.com/ershoufang/103122651285...   卧龙天香南园
# ...      ...  ...                                                ...      ...
# 13285  13290  越城区  https://sx.lianjia.com/ershoufang/103121132246...     南星公寓
# 13286  13291  越城区  https://sx.lianjia.com/ershoufang/103119135871...     绍兴艺境
# 13287  13292  越城区  https://sx.lianjia.com/ershoufang/103120662261...     水墨澜庭
# 13288  13293  越城区  https://sx.lianjia.com/ershoufang/103113852581...      御和园
# 13289  13294  越城区  https://sx.lianjia.com/ershoufang/103117268044...    宏大美安居
#
#          位置    户型      面积   朝向 装修风格      均价         总价
# 0      上虞城西  3室1厅  130.85    南   简装  220.8万  16,875元/平
# 1      上虞城北  3室2厅  158.48    南   精装    280万  17,668元/平
# 2      上虞城南  3室2厅  136.00    南   精装  262.8万  19,324元/平
# 3       开发区  3室1厅   86.40    南   精装    190万  21,991元/平
# 4       开发区  4室2厅  139.03    南   毛坯    210万  15,105元/平
# ...     ...   ...     ...  ...  ...     ...        ...
# 13285    斗门  3室2厅  142.69    南   其他    145万  10,162元/平
# 13286    斗门  4室2厅  127.00    南   其他    230万  18,111元/平
# 13287    城南  5室2厅  226.00  南 北   其他    560万  24,779元/平
# 13288    镜湖  3室2厅  123.00    南   其他    332万  26,992元/平
# 13289    两湖  5室2厅  209.00  南 北   毛坯    180万   8,613元/平
#
# [13290 rows x 11 columns]

# %% [markdown]
# ## 4图表分析

# %% [markdown]
# ### 4.1 房源数量、位置分布分析

# %%
 # 创建一个DataFrame对象，该对象只有两列数据：区域和数量
new_df = pd.DataFrame({'区域':file_data['区域'].unique(),'数量':[0]*6})
new_df
# Out:
#     区域  数量
# 0  上虞区   0
# 1  嵊州市   0
# 2  新昌县   0
# 3  柯桥区   0
# 4  诸暨市   0
# 5  越城区   0

# %%
# 按“区域”列将file_data进行分组，并统计每个分组的数量
groupy_area = file_data.groupby(by='区域').count()
new_df['数量'] = groupy_area.values
new_df
# Out:
#     区域    数量
# 0  上虞区  3000
# 1  嵊州市  1275
# 2  新昌县    18
# 3  柯桥区  2999
# 4  诸暨市  2998
# 5  越城区  3000

# %%
# 按“数量”一列从大到小排列
new_df.sort_values(by=['数量'], ascending=False)
# Out:
#     区域    数量
# 0  上虞区  3000
# 5  越城区  3000
# 3  柯桥区  2999
# 4  诸暨市  2998
# 1  嵊州市  1275
# 2  新昌县    18

# %%
# 增加位置一列
file_data['位置'] = '绍兴市'+file_data['区域'].values + file_data['小区名称'].values
file_data
# Out:
#           id   区域                                                 链接     小区名称  \
# 0          1  上虞区  https://sx.lianjia.com/ershoufang/103122982067...   闰土•嘉和園
# 1          2  上虞区  https://sx.lianjia.com/ershoufang/103122914260...    绿城桂花园
# 2          3  上虞区  https://sx.lianjia.com/ershoufang/103122978023...     南都花园
# 3          4  上虞区  https://sx.lianjia.com/ershoufang/103122657260...  卧龙·天香西园
# 4          5  上虞区  https://sx.lianjia.com/ershoufang/103122651285...   卧龙天香南园
# ...      ...  ...                                                ...      ...
# 13285  13290  越城区  https://sx.lianjia.com/ershoufang/103121132246...     南星公寓
# 13286  13291  越城区  https://sx.lianjia.com/ershoufang/103119135871...     绍兴艺境
# 13287  13292  越城区  https://sx.lianjia.com/ershoufang/103120662261...     水墨澜庭
# 13288  13293  越城区  https://sx.lianjia.com/ershoufang/103113852581...      御和园
# 13289  13294  越城区  https://sx.lianjia.com/ershoufang/103117268044...    宏大美安居
#
#                   位置    户型      面积   朝向 装修风格      均价         总价
# 0       绍兴市上虞区闰土•嘉和園  3室1厅  130.85    南   简装  220.8万  16,875元/平
# 1        绍兴市上虞区绿城桂花园  3室2厅  158.48    南   精装    280万  17,668元/平
# 2         绍兴市上虞区南都花园  3室2厅  136.00    南   精装  262.8万  19,324元/平
# 3      绍兴市上虞区卧龙·天香西园  3室1厅   86.40    南   精装    190万  21,991元/平
# 4       绍兴市上虞区卧龙天香南园  4室2厅  139.03    南   毛坯    210万  15,105元/平
# ...              ...   ...     ...  ...  ...     ...        ...
# 13285     绍兴市越城区南星公寓  3室2厅  142.69    南   其他    145万  10,162元/平
# 13286     绍兴市越城区绍兴艺境  4室2厅  127.00    南   其他    230万  18,111元/平
# 13287     绍兴市越城区水墨澜庭  5室2厅  226.00  南 北   其他    560万  24,779元/平
# 13288      绍兴市越城区御和园  3室2厅  123.00    南   其他    332万  26,992元/平
# 13289    绍兴市越城区宏大美安居  5室2厅  209.00  南 北   毛坯    180万   8,613元/平
#
# [13290 rows x 11 columns]

# %%
# 获取经纬度
# coding=utf-8
import requests
import pandas as pd
import time
import json


class LngLat:
    # 获取位置一列的数据
    def get_data(self):
        house_names = file_data['位置']
        house_names = house_names.tolist()
        return house_names

    def get_url(self):
        url_temp = "http://api.map.baidu.com/geocoding/v3/?address={}&output=json&ak=1GSaIGDVXnCYVZLBqP9bLpKDojwGwmUe&callback=showLocation"
        house_names = self.get_data()
        return [url_temp.format(i) for i in house_names]

    # 发送请求
    def parse_url(self, url):
        while 1:
            try:
                r = requests.get(url)
            except requests.exceptions.ConnectionError:
                time.sleep(2)
                continue
            return r.content.decode('UTF-8')

    def run(self):
        li = []
        urls = self.get_url()
        # i = 0
        for url in urls:
            # print(i)
            # i += 1
            data = self.parse_url(url)
            str = data.split("{")[-1].split("}")[0]
            try:
                lng = float(str.split(",")[0].split(":")[1])
                lat = float(str.split(",")[1].split(":")[1])
            except ValueError:
                continue
            # 构建字典
            dict_data = dict(lng=lng, lat=lat, count=1)
            li.append(dict_data)
        f = open(r'D:\Documents\Codebase\Analysis\BigJob\shen\经纬度信息.txt', 'w')
        f.write(json.dumps(li))
        f.close()
        print('正在写入...')
        print('写入成功')


if __name__ == '__main__':
    execute = LngLat()
    execute.run()
# 输出结果如下
'正在写入...'
'写入成功'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [58], line 57
#      55 if __name__ == '__main__':
#      56     execute = LngLat()
# ---> 57     execute.run()
#      58 # 输出结果如下
#      59 '正在写入...'
#
# Cell In [58], line 41, in LngLat.run(self)
#      39 str = data.split("{")[-1].split("}")[0]
#      40 try:
# ---> 41     lng = float(str.split(",")[0].split(":")[1])
#      42     lat = float(str.split(",")[1].split(":")[1])
#      43 except ValueError:
#
# IndexError: list index out of range

# %% [markdown]
# ### 4.2 户型数量分析

# %%
# 定义函数，用于计算各户型的数量
def all_house(arr):
    arr = np.array(arr)
    key = np.unique(arr)
    result = {}
    for k in key:
        mask = (arr == k)
        arr_new = arr[mask]
        v = arr_new.size
        result[k] = v
    return result
# 获取户型数据
house_array = file_data['户型']
house_info = all_house(house_array)
house_info
# Out:
# {'0室1厅': 1,
#  '12室3厅': 1,
#  '13室1厅': 1,
#  '1室0厅': 14,
#  '1室1厅': 302,
#  '1室2厅': 9,
#  '2室0厅': 4,
#  '2室1厅': 1028,
#  '2室2厅': 770,
#  '2室3厅': 2,
#  '3室0厅': 2,
#  '3室1厅': 1323,
#  '3室2厅': 5686,
#  '3室3厅': 12,
#  '4室0厅': 3,
#  '4室1厅': 231,
#  '4室2厅': 2558,
#  '4室3厅': 86,
#  '4室4厅': 3,
#  '5室1厅': 31,
#  '5室2厅': 712,
#  '5室3厅': 188,
#  '5室4厅': 6,
#  '5室5厅': 1,
#  '6室1厅': 15,
#  '6室2厅': 150,
#  '6室3厅': 68,
#  '6室4厅': 11,
#  '7室1厅': 5,
#  '7室2厅': 18,
#  '7室3厅': 11,
#  '7室4厅': 4,
#  '7室5厅': 1,
#  '8室0厅': 1,
#  '8室1厅': 2,
#  '8室2厅': 9,
#  '8室3厅': 11,
#  '8室4厅': 1,
#  '9室1厅': 1,
#  '9室2厅': 3,
#  '9室3厅': 3,
#  '9室4厅': 2}

# %%
# 使用字典推导式
house_type = dict((key, value) for key, value 
in house_info.items() if value > 50)
show_houses = pd.DataFrame({'户型':[x for x in  house_type.keys()],
                  '数量':[x for x in house_type.values()]})
show_houses
# Out:
#       户型    数量
# 0   1室1厅   302
# 1   2室1厅  1028
# 2   2室2厅   770
# 3   3室1厅  1323
# 4   3室2厅  5686
# 5   4室1厅   231
# 6   4室2厅  2558
# 7   4室3厅    86
# 8   5室2厅   712
# 9   5室3厅   188
# 10  6室2厅   150
# 11  6室3厅    68

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus'] = False
house_type = show_houses['户型']
house_type_num = show_houses['数量']
plt.barh(range(11), house_type_num, height=0.7, 
color='steelblue', alpha=0.8)     
plt.yticks(range(11), house_type)
plt.xlim(0,2500)
plt.xlabel("数量")
plt.ylabel("户型种类")
plt.title("绍兴地区各户型房屋数量")
for x, y in enumerate(house_type_num):
    plt.text(y + 0.2, x - 0.1, '%s' % y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [57], line 8
#       6 house_type = show_houses['户型']
#       7 house_type_num = show_houses['数量']
# ----> 8 plt.barh(range(11), house_type_num, height=0.7,
#       9 color='steelblue', alpha=0.8)
#      10 plt.yticks(range(11), house_type)
#      11 plt.xlim(0,2500)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py:2375, in barh(y, width, height, left, align, data, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.barh)
#    2372 def barh(
#    2373         y, width, height=0.8, left=None, *, align='center',
#    2374         data=None, **kwargs):
# -> 2375     return gca().barh(
#    2376         y, width, height=height, left=left, align=align,
#    2377         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py:2615, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2505 r"""
#    2506 Make a horizontal bar plot.
#    2507
#    (...)
#    2612 :doc:`/gallery/lines_bars_and_markers/horizontal_barchart_distribution`.
#    2613 """
#    2614 kwargs.setdefault('orientation', 'horizontal')
# -> 2615 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2616                    align=align, data=data, **kwargs)
#    2617 return patches
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py:2383, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2380     if yerr is not None:
#    2381         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2383 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2384     # Make args iterable too.
#    2385     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2387 # Now that units have been converted, set the tick locations.
#    2388 if orientation == 'vertical':
#
# File <__array_function__ internals>:180, in broadcast_arrays(*args, **kwargs)
#
# File d:\Program Files\Python39\lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File d:\Program Files\Python39\lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 2 with shape (12,) and arg 3 with shape (11,).

# %% [markdown]
# ### 4.3 平均房价分析

# %%
# 新建一个DataFrame对象，设置房价总金额和总面积初始值为0
df_all = pd.DataFrame({'区域':file_data['区域'].unique(),
                         '房价总金额':[0]*6,
                         '总面积':[0]*6})
df_all
# Out:
#        区域  房租总金额  总面积(㎡)
# 0      东城      0       0
# 1      丰台      0       0
# 2   亦庄开发区      0       0
# 3      大兴      0       0
# 4      房山      0       0
# 5      昌平      0       0
# 6      朝阳      0       0
# 7      海淀      0       0
# 8     石景山      0       0
# 9      西城      0       0
# 10     通州      0       0
# 11    门头沟      0       0
# 12     顺义      0       0

# %%
# 求总金额和总面积
sum_price = file_data['价格'].groupby(file_data['区域']).sum()
sum_area = file_data['面积'].groupby(file_data['区域']).sum()
df_all['房价总金额'] = sum_price.values
df_all['总面积'] = sum_area.values
df_all
# Out:
#        区域     房租总金额     总面积(㎡)
# 0      东城   3945550   27353.99
# 1      丰台   4404893   50922.79
# 2   亦庄开发区   1318400   15995.53
# 3      大兴   2286950   35884.15
# 4      房山    726750   15275.41
# 5      昌平   2521515   35972.92
# 6      朝阳  20281396  166921.72
# 7      海淀   7279350   57210.39
# 8     石景山   1156500   13956.67
# 9      西城   5636975   37141.64
# 10     通州   2719600   46625.23
# 11    门头沟   1048300   20258.20
# 12     顺义   2190900   33668.97

# %%
# 计算各区域每平米房价价格,并保留两位小数
df_all['每平米房价(元)'] = round(df_all['房价总金额']/ df_all ['总面积'], 2)
df_all
# Out:
#        区域     房租总金额     总面积(㎡)  每平米租金(元)
# 0      东城   3945550   27353.99    144.24
# 1      丰台   4404893   50922.79     86.50
# 2   亦庄开发区   1318400   15995.53     82.42
# 3      大兴   2286950   35884.15     63.73
# 4      房山    726750   15275.41     47.58
# 5      昌平   2521515   35972.92     70.09
# 6      朝阳  20281396  166921.72    121.50
# 7      海淀   7279350   57210.39    127.24
# 8     石景山   1156500   13956.67     82.86
# 9      西城   5636975   37141.64    151.77
# 10     通州   2719600   46625.23     58.33
# 11    门头沟   1048300   20258.20     51.75
# 12     顺义   2190900   33668.97     65.07

# %%
# 合并new_df与df_all
df_merge = pd.merge(new_df, df_all)
df_merge
# Out:
#        区域    数量     房租总金额     总面积(㎡)  每平米租金(元)
# 0      东城   282   3945550   27353.99    144.24
# 1      丰台   577   4404893   50922.79     86.50
# 2   亦庄开发区   147   1318400   15995.53     82.42
# 3      大兴   362   2286950   35884.15     63.73
# 4      房山   180    726750   15275.41     47.58
# 5      昌平   347   2521515   35972.92     70.09
# 6      朝阳  1597  20281396  166921.72    121.50
# 7      海淀   605   7279350   57210.39    127.24
# 8     石景山   175   1156500   13956.67     82.86
# 9      西城   442   5636975   37141.64    151.77
# 10     通州   477   2719600   46625.23     58.33
# 11    门头沟   285   1048300   20258.20     51.75
# 12     顺义   297   2190900   33668.97     65.07

# %%
import matplotlib.ticker as mtick
from matplotlib.font_manager import FontProperties
num= df_merge['数量']                 # 数量
price=df_merge['每平米房价(元)'] # 价格
l=[i for i in range(6)]
plt.rcParams['font.sans-serif']=['SimHei'] 
lx=df_merge['区域']
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(l, price,'or-',label='价格')
for i,(_x,_y) in enumerate(zip(l,price)):
    plt.text(_x,_y,price[i],color='black',fontsize=10)  
ax1.set_ylim([0, 200])
ax1.set_ylabel('价格')
plt.legend(prop={'family':'SimHei','size':8},loc='upper left') 
ax2 = ax1.twinx()
plt.bar(l,num,alpha=0.3,color='green',label='数量')
ax2.set_ylabel('数量')
ax2.set_ylim([0, 2000])  
plt.legend(prop={'family':'SimHei','size':8},loc="upper right")
plt.xticks(l,lx)
plt.show()

# %% [markdown]
# ### 4.4 面积区间分析

# %%
# 查看房屋的最大面积和最小面积
print('房屋最大面积是%d平米'%(file_data['面积'].max()))
print('房屋最小面积是%d平米'%(file_data['面积'].min()))
# 查看房价的最高值和最小值
print('房价最高价格为每月%d元'%(file_data['价格'].max()))
print('房屋最低价格为每月%d元'%(file_data['价格'].min()))
# Out:
# 房屋最大面积是1133平米
# 房屋最小面积是11平米
# 房租最高价格为每月150000元
# 房屋最低价格为每月566元

# %%
# 面积划分
area_divide = [1, 30, 50, 70, 90, 120, 140, 160, 1200]
area_cut = pd.cut(list(file_data['面积']), area_divide)
area_cut_data = area_cut.describe()
area_cut_data
# Out:
#              counts     freqs
# categories
# (1, 30]          41  0.007102
# (30, 50]        710  0.122986
# (50, 70]       1566  0.271263
# (70, 90]       1094  0.189503
# (90, 120]      1082  0.187424
# (120, 140]      381  0.065997
# (140, 160]      274  0.047462
# (160, 1200]     625  0.108263

# %%
import numpy as np
area_percentage = (area_cut_data['freqs'].values)*100
# 保留两位小数
np.set_printoptions(precision=2)
labels  = ['30平米以下', '30-50平米', '50-70平米', '70-90平米',
'90-120平米','120-140平米','140-160平米','160平米以上']
plt.axes(aspect=1)
plt.pie(x=area_percentage, labels=labels, autopct='%.2f %%',
           shadow=True, labeldistance=1.2, startangle = 90,pctdistance = 0.7)
plt.legend(loc='upper right')
plt.show()
